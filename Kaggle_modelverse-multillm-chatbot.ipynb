# %%
import shutil, os

src = "/kaggle/input/datasets/ibadatafridi/chatbotdata"
dst = "/kaggle/working"

for f in os.listdir(src):
    full_path = os.path.join(src, f)
    if os.path.isfile(full_path):
        shutil.copy(full_path, dst)

print("Copied files:", os.listdir(dst))

# %%
# !pip install -r /kaggle/working/requirements.txt --quiet
# !pip install pyngrok --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.6/797.6 kB 24.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.8/221.8 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.2/119.2 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.0/352.0 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 80.0 MB/s eta 0:00:00:00:01
# ...

# %%
import streamlit, openai, groq, google.genai, mistralai, cohere
print("All core packages imported successfully ✅")
# Out:
# All core packages imported successfully ✅

# %%
from kaggle_secrets import UserSecretsClient
import os

secrets = UserSecretsClient()

os.environ["OPENAI_API_KEY"] = secrets.get_secret("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"] = secrets.get_secret("GROQ_API_KEY")
os.environ["GEMINI_API_KEY"] = secrets.get_secret("GEMINI_API_KEY")
os.environ["CEREBRAS_API_KEY"] = secrets.get_secret("CEREBRAS_API_KEY")
os.environ["MISTRAL_API_KEY"] = secrets.get_secret("MISTRAL_API_KEY")
os.environ["COHERE_API_KEY"] = secrets.get_secret("COHERE_API_KEY")
os.environ["Z_AI_API_KEY"] = secrets.get_secret("Z_AI_API_KEY")

print("Secrets loaded ✅")
# Out:
# Secrets loaded ✅

# %%
from pyngrok import ngrok
ngrok.kill()

# %%
import subprocess, time
from pyngrok import ngrok

ngrok.set_auth_token(secrets.get_secret("NGROK_TOKEN"))

process = subprocess.Popen(
    ["streamlit", "run", "app.py",
     "--server.port=8501",
     "--server.headless=true",
     "--server.enableCORS=false"],
    cwd="/kaggle/working"
)

time.sleep(6)

public_url = ngrok.connect(8501)
print("Your app is live at:", public_url)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_58/36783480.py in <cell line: 0>()
#       1 import subprocess, time
# ----> 2 from pyngrok import ngrok
#       3
#       4 ngrok.set_auth_token(secrets.get_secret("NGROK_TOKEN"))
#       5
#
# ModuleNotFoundError: No module named 'pyngrok'

# %%
from pyngrok import ngrok
ngrok.kill()
